# %% [markdown]
# <a href="https://colab.research.google.com/github/aacasallas/TalentoTech_AlvaroCasallas/blob/main/Taller_Iniciacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importa la libreria de pandas que sirve para la manipulacion de datos
import pandas as pd

# %%
df_1=pd.read_csv("/content/DataSet1.csv",delimiter=';')

# %%
#head solo muestra los 10 primeros datos
df_1.head()
# Out:
#     id weight height   age gender  \
# 0  1.0  144,5    5,9  33.0      M
# 1  2.0  167,2    5,4  45.0      M
# 2  3.0  124,1    5,2  23.0      F
# 3  4.0  144,5    5,9  33.0      M
# 4  5.0  133,2    5,7  54.0      F
#
#                                       Respuestas
# 0  1. Tipo de datos: numericos, decimales, texto
# 1                       2.Cantidad de datos : 35
# 2               3. Caracteristicas de los datos:
# 3                                  4. Patrones:
# 4                                 5. Tendencias:

# %%
#se copia el contenido del primer dataframe en el segundo dataframe creado
df_2=df_1

# %%
df_3= pd.read_excel("/content/example_ventas.xlsx")

# %%
df_3
# Out:
#         Fecha   Region      Producto Vendedor  Ventas
# 0  2024-01-31  Central    Accesorios    David    8287
# 1  2024-02-01  Central    Accesorios    Karen    6909
# 2  2024-02-02  Central  Dispositivos    David   11420
# 3  2024-02-03  Central  Dispositivos    Karen   12948
# 4  2024-02-04  Central      Sistemas    David   20098
# 5  2024-02-05  Central      Sistemas    Karen   30633
# 6  2024-02-06     Este    Accesorios      Ana    9323
# 7  2024-02-07     Este    Accesorios    Lucas    7667
# 8  2024-02-08     Este  Dispositivos      Ana   10348
# 9  2024-02-09     Este  Dispositivos    Lucas    9312
# 10 2024-02-10     Este      Sistemas      Ana   13531
# 11 2024-02-11     Este      Sistemas    Lucas   13374
# 12 2024-02-12    Oeste    Accesorios    Kevin    4744
# 13 2024-02-13    Oeste    Accesorios     Sara    5442
# 14 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 15 2024-02-15    Oeste  Dispositivos     Sara    8780
# ...

# %%
#Ejercicio 1: mostrar las primeras filas del dataframe
print("Ejercicio 1: Mostrar las primeras filas del Dataframe")
print(df_3.head(5))
# Out:
# Ejercicio 1: Mostrar las primeras filas del Dataframe
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-01-31  Central    Accesorios    David    8287
# 1 2024-02-01  Central    Accesorios    Karen    6909
# 2 2024-02-02  Central  Dispositivos    David   11420
# 3 2024-02-03  Central  Dispositivos    Karen   12948
# 4 2024-02-04  Central      Sistemas    David   20098

# %%
#Ejercicio 2: Calcular el total de ventas por region
print("Ejercicio 2: Calcular el total de ventas por region")
print(df_3.groupby('Region')['Ventas'].sum())
# Out:
# Ejercicio 2: Calcular el total de ventas por region
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64

# %%
#Ejercicio 2: Calcular el total de ventas por region
print("Ejercicio 2: Calcular el total de ventas por region")
ventas_por_region = df_3.groupby('Region')['Ventas'].sum()
print(ventas_por_region)
print("\n")
print(df_3.head(10))
# Out:
# Ejercicio 2: Calcular el total de ventas por region
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64
#
#
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-01-31  Central    Accesorios    David    8287
# 1 2024-02-01  Central    Accesorios    Karen    6909
# 2 2024-02-02  Central  Dispositivos    David   11420
# 3 2024-02-03  Central  Dispositivos    Karen   12948
# 4 2024-02-04  Central      Sistemas    David   20098
# 5 2024-02-05  Central      Sistemas    Karen   30633
# 6 2024-02-06     Este    Accesorios      Ana    9323
# 7 2024-02-07     Este    Accesorios    Lucas    7667
# 8 2024-02-08     Este  Dispositivos      Ana   10348
# 9 2024-02-09     Este  Dispositivos    Lucas    9312

# %%
#Ejercicio 3 ventas de David
Ventas_david=df_3[df_3['Vendedor']=='David']
print(Ventas_david)
# Out:
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-01-31  Central    Accesorios    David    8287
# 2 2024-02-02  Central  Dispositivos    David   11420
# 4 2024-02-04  Central      Sistemas    David   20098

# %%
# ventas mayores a 10000 por region, si cambias el ascending dependiendo el true
# or false puedes ponerlo de menor a mayor y vicebersa
df_filtrada=df_3[df_3['Ventas']>10000].sort_values(by='Ventas',ascending=False)
print(df_filtrada)
# Out:
#         Fecha   Region      Producto Vendedor  Ventas
# 16 2024-02-16    Oeste      Sistemas    Kevin   32855
# 5  2024-02-05  Central      Sistemas    Karen   30633
# 17 2024-02-17    Oeste      Sistemas     Sara   23151
# 4  2024-02-04  Central      Sistemas    David   20098
# 10 2024-02-10     Este      Sistemas      Ana   13531
# 11 2024-02-11     Este      Sistemas    Lucas   13374
# 3  2024-02-03  Central  Dispositivos    Karen   12948
# 2  2024-02-02  Central  Dispositivos    David   11420
# 14 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 8  2024-02-08     Este  Dispositivos      Ana   10348

# %%
#Eliminar columna vendedor
df_eliminado=df_3.drop(columns='Vendedor')
print(df_eliminado)
# Out:
#         Fecha   Region      Producto  Ventas
# 0  2024-01-31  Central    Accesorios    8287
# 1  2024-02-01  Central    Accesorios    6909
# 2  2024-02-02  Central  Dispositivos   11420
# 3  2024-02-03  Central  Dispositivos   12948
# 4  2024-02-04  Central      Sistemas   20098
# 5  2024-02-05  Central      Sistemas   30633
# 6  2024-02-06     Este    Accesorios    9323
# 7  2024-02-07     Este    Accesorios    7667
# 8  2024-02-08     Este  Dispositivos   10348
# 9  2024-02-09     Este  Dispositivos    9312
# 10 2024-02-10     Este      Sistemas   13531
# 11 2024-02-11     Este      Sistemas   13374
# 12 2024-02-12    Oeste    Accesorios    4744
# 13 2024-02-13    Oeste    Accesorios    5442
# 14 2024-02-14    Oeste  Dispositivos   10711
# 15 2024-02-15    Oeste  Dispositivos    8780
# 16 2024-02-16    Oeste      Sistemas   32855
# 17 2024-02-17    Oeste      Sistemas   23151

# %%
import pandas as pd

# Cargar el archivo CSV
from google.colab import files
uploaded = files.upload()

# Leer el archivo CSV (asegúrate de que el archivo se llame 'Ventas_Dataset.csv')
df_ventas = pd.read_csv('Ventas_Dataset.csv', delimiter=';')

# Limpiar los nombres de las columnas
df_ventas.columns = df_ventas.columns.str.strip()

# Ejercicio 1: Mostrar las primeras filas del DataFrame
print("Ejercicio 1: Mostrar las primeras filas del DataFrame")
print(df_ventas.head(5))
# Out:
#      <input type="file" id="files-d2695026-aeeb-478b-8b20-da7b4b1a4468" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2695026-aeeb-478b-8b20-da7b4b1a4468">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
